# %%
import matplotlib as pl
import numpy as np

# %%
print(pl.__version__)
# Out:
# 3.7.1

# %%
np.__version__
# Out:
# '1.24.3'

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([0,6])

# %%
x
# Out:
# array([0, 6])

# %%
y=np.array([0,250] )

# %%
y
# Out:
# array([  0, 250])

# %%
plt.plot(x,y)

# %%
plt.plot(y,x)

# %%
plt.plot(y,x,"o")

# %%
x1=np.array([1,2,3,5,6])
y1=np.array([23,26,34,32,20])

# %%
plt.plot(x1,y1)

# %%
p=np.array([2,4,5,12,23,43])

# %%
plt.plot(p)

# %%
plt.plot(x1,y1,"o")

# %%
plt.plot(x1,y1,marker='o')

# %%
plt.plot(x1,y1,marker='*')

# %% [raw]
#  **Markers**
#
# =============   ===============================
# character       description
# =============   ===============================
# ``'.'``         point marker
# ``','``         pixel marker
# ``'o'``         circle marker
# ``'v'``         triangle_down marker
# ``'^'``         triangle_up marker
# ``'<'``         triangle_left marker
# ``'>'``         triangle_right marker
# ``'1'``         tri_down marker
# ``'2'``         tri_up marker
# ``'3'``         tri_left marker
# ``'4'``         tri_right marker
# ``'8'``         octagon marker
# ``'s'``         square marker
# ``'p'``         pentagon marker
# ``'P'``         plus (filled) marker
# ``'*'``         star marker
# ``'h'``         hexagon1 marker
# ``'H'``         hexagon2 marker
# ``'+'``         plus marker
# ``'x'``         x marker
# ``'X'``         x (filled) marker
# ``'D'``         diamond marker
# ``'d'``         thin_diamond marker
# ``'|'``         vline marker
# ``'_'``         hline marker
# =============   ===============================

# %%
plt.plot(x1,y1,marker='o',color='red')

# %%
plt.plot(x1,y1,marker='o',color='m')

# %%
plt.plot(x1,y1,'*''y')

# %% [raw]
# The supported color abbreviations are the single letter codes
#
# =============    ===============================
# character        color
# =============    ===============================
# ``'b'``          blue
# ``'g'``          green
# ``'r'``          red
# ``'c'``          cyan
# ``'m'``          magenta
# ``'y'``          yellow
# ``'k'``          black
# ``'w'``          white
# =============    ===============================

# %%
plt.plot(x1,y1,marker='o',color='red',linestyle='--')

# %%
plt.plot(x1,y1,marker="*",color="c",linestyle='-.')

# %%
plt.plot(x1,y1,'*:c')

# %% [raw]
# **Line Styles**
#
# =============    ===============================
# character        description
# =============    ===============================
# ``'-'``          solid line style
# ``'--'``         dashed line style
# ``'-.'``         dash-dot line style
# ``':'``          dotted line style
# =============    ===============================

# %%
plt.plot(x1,y1,'*',ms=10) #marker size(ms)

# %%
plt.plot(x1,y1,'*',ms=30)

# %%
plt.plot(x1,y1,'o--g',ms=15)

# %%
plt.plot(x1,y1,'o--g',ms=15,mec='r')# marker edge color-mec

# %%
plt.plot(x1,y1,'o--g',ms=15,mec='k')

# %%
plt.plot(x1,y1,'o--g',ms=15,mfc='y') #marker face color (mfc)

# %%
plt.plot(x1,y1,'*:g',ms=14,mfc='k')

# %%
plt.plot(x1,y1,'o:y',ms=18,mec='k',mfc='g')

# %% [markdown]
# # linestyle or ls
# - is used to change the style of the plotted line

# %%
plt.plot(x1,y1,ls=':') #linestyle(ls)

# %%
plt.plot(x1,y1,ls='--')

# %% [markdown]
# # line width

# %%
plt.plot(x1,y1)

# %%
plt.plot(x1,y1,linewidth='10')

# %%
plt.plot(x1,y1,'g',linewidth="5.5")

# %% [markdown]
# # Create labels for a plot

# %%
x2=np.array([30,35,40,45,50,55,60,65,70,75])
y2=np.array([100,105,110,115,120,125,130,135,140,145])

# %%
plt.plot(x2,y2)

# %%
plt.xlabel('oxygen')
plt.ylabel('water')
# Out:
# Text(0, 0.5, 'water')

# %%
plt.plot(x2,y2)
plt.xlabel('oxygen')
plt.ylabel('water')
# Out:
# Text(0, 0.5, 'water')

# %% [markdown]
# ### Title for the plot

# %%
plt.title('Earth')
# Out:
# Text(0.5, 1.0, 'Earth')

# %%
plt.plot(x2,y2)
plt.title('Earth')
plt.xlabel('oxygen')
plt.ylabel('water')
# Out:
# Text(0, 0.5, 'water')

# %% [markdown]
# #### Font property for title and labels

# %%
f1={'family':'serif','color':'pink','size':20}
f2={'family':'serif','color':'darkred','size':25}

# %%
plt.plot(x2,y2)
plt.title('Earth',f2)
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
# Out:
# Text(0, 0.5, 'water')

# %% [markdown]
# ## Change the location of title

# %%
plt.plot(x2,y2)
plt.title('Earth',f2)
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
# Out:
# Text(0, 0.5, 'water')

# %%
plt.plot(x2,y2)
plt.title('Earth',f2,loc='left')# location (loc)
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
# Out:
# Text(0, 0.5, 'water')

# %%
plt.plot(x2,y2)
plt.title('Earth',f2,loc='right')
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
# Out:
# Text(0, 0.5, 'water')

# %% [markdown]
# # Adding the grid lines to a plot

# %%
plt.grid()

# %%
plt.plot(x2,y2)
plt.title('Earth',f2)
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
plt.grid()

# %% [markdown]
# <h5>Now we will specify which grid line to display
#
#     x axis or y axis

# %%
plt.grid(axis='x')

# %%
plt.grid(axis='y')

# %% [markdown]
# <h5>line properties for the grid<h5>

# %%
plt.plot(x2,y2)
plt.title('Earth',f2)
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
plt.grid(color='pink',ls='--',linewidth=1)

# %%
plt.plot(x2,y2)
plt.title('Earth',f2)
plt.xlabel('oxygen',f1)
plt.ylabel('water',f1)
plt.grid(color='orange',ls='--',linewidth=1)

# %% [markdown]
# # Display the multiple plots

# %%
x3=np.array([0,2,4,6,8])
y3=np.array([5,3,6,3,12])
plt.subplot(1,2,1) # (rows, columns, panel number)
x4=np.array([1,2,3,4,5,6])
y4=np.array([0,30,24,35,43,29])
plt.subplot(1,2,2) # (rows, columns, panel number)
# Out:
# <Axes: >

# %%
x3=np.array([0,2,4,6,8])
y3=np.array([5,3,6,3,12])          
plt.subplot(1,2,1) # (rows, columns, panel number)
plt.plot(x3,y3) 
plt.title('1st plot')


x4=np.array([1,2,3,4,5,6])
y4=np.array([0,30,24,35,43,29])
plt.subplot(1,2,2) # (rows, columns, panel number)
plt.plot(x4,y4)
plt.title('2nd plot')
# Out:
# Text(0.5, 1.0, '2nd plot')

# %%
x3=np.array([0,2,4,6,8])
y3=np.array([5,3,6,3,12])          
plt.subplot(2,1,1) # (rows, columns, panel number)
plt.plot(x3,y3) 
plt.title('1st plot')




x4=np.array([1,2,3,4,5,6])
y4=np.array([0,30,24,35,43,29])
plt.subplot(2,1,2) # (rows, columns, panel number)
plt.plot(x4,y4)
plt.title('2nd plot')
# Out:
# Text(0.5, 1.0, '2nd plot')

# %%
x3=np.array([0,2,4,6,8])
y3=np.array([5,3,6,3,12])          
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.plot(x3,y3) 
plt.title('1st plot')


x4=np.array([1,2,3,4,5,6])
y4=np.array([0,30,24,35,43,29])
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.plot(x4,y4)
plt.title('2nd plot')



x5=np.array([11,22,33,44,55,66])
y5=np.array([10,60,34,45,55,40])
plt.subplot(2,2,3) # (rows, columns, panel number)
plt.plot(x5,y5)
plt.title('3nd plot')
# Out:
# Text(0.5, 1.0, '3nd plot')

# %%
x3=np.array([0,2,4,6,8])
y3=np.array([5,3,6,3,12])          
plt.subplot(2,2,1) # (rows, columns, panel number)
plt.plot(x3,y3) 
plt.title('1st plot')


x4=np.array([1,2,3,4,5,6])
y4=np.array([0,30,24,35,43,29])
plt.subplot(2,2,2) # (rows, columns, panel number)
plt.plot(x4,y4)
plt.title('2nd plot')



x5=np.array([11,22,33,44,55,66])
y5=np.array([10,60,34,45,55,40])
plt.subplot(2,2,3) # (rows, columns, panel number)
plt.plot(x5,y5)
plt.title('3rd plot')


x6=np.array([110,220,330,440,550,660])
y6=np.array([100,600,340,450,550,400])
plt.subplot(2,2,4) # (rows, columns, panel number)
plt.plot(x6,y6)
plt.title('4th plot')


plt.suptitle('plots',color='red',size=20)
# Out:
# Text(0.5, 0.98, 'plots')

# %% [markdown]
# # Scatter
# the scatter() function plots oe for each observation...

# %%
print(plt.scatter(x4,y4))
# Out:
# <matplotlib.collections.PathCollection object at 0x0000020848AFCB90>

# %%
print(plt.scatter(x5,y5))
# Out:
# <matplotlib.collections.PathCollection object at 0x0000020848A06AD0>

# %%
x7=np.array([15,18,25,15,30,50])
y7=np.array([18,45,15,20,32,35])

# %%
print(plt.scatter(x5,y5,color='darkred'))
print(plt.scatter(x7,y7,color='hotpink'))
# Out:
# <matplotlib.collections.PathCollection object at 0x0000020848CEE490>
# <matplotlib.collections.PathCollection object at 0x0000020848D00B90>

# %% [markdown]
# # Change the color for dots

# %%
print(plt.scatter(x4,y4))
# Out:
# <matplotlib.collections.PathCollection object at 0x0000020848C97490>

# %%
c1=(['red','purple','pink','cyan','orange','red'])

# %%
print(plt.scatter(x4,y4,c=c1))
# Out:
# <matplotlib.collections.PathCollection object at 0x000002084887F750>

# %% [markdown]
# # Specify a colormap in scatter plot

# %%
c1=np.array([0,10,20,30,40,50])
plt.scatter(x4,y4,c=c1,cmap='viridis')

# %% [markdown]
# # Specify a colorbar in scatter plot

# %%
plt.scatter(x4,y4,c=c1,cmap='viridis')
plt.colorbar()

# %%
c1=np.array([70,10,200,340,240,50])
plt.scatter(x4,y4,c=c1,cmap='viridis',s=c1)
plt.colorbar()

# %% [markdown]
# # Alpha
# Adjust the transprency of the dots

# %%
plt.scatter(x4,y4,c=c1,cmap='viridis',s=c1,alpha=0.3)
plt.colorbar()

# %% [markdown]
# # Create bars--(bar())

# %%
x8=np.array(["A","B","C","D","E"])
y8=np.array([12,34,45,65,20])

# %%
plt.plot(x8,y8)

# %%
plt.scatter(x8,y8)

# %% [markdown]
# # Vertical bar

# %%
plt.bar(x8,y8) #(bar())
plt.title('BAR PLOT',color='darkred')
# Out:
# Text(0.5, 1.0, 'BAR PLOT')

# %% [markdown]
# # Horizontal bar

# %%
plt.barh(x8,y8) #(bar())
plt.title('BAR PLOT',color='pink')
# Out:
# Text(0.5, 1.0, 'BAR PLOT')

# %%
plt.barh(x8,y8) #(bar())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x8,y8,color='gold') #(bar())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x8,y8,color='gold',width=0.3)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# <h3>****** For horizontal to use height insted of width*****<h3>

# %%
plt.barh(x8,y8,color='gold',height=0.5)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Histogram

# %%
d1 = np.random.normal(10,20,100)
plt.hist(d1)
# Out:
# (array([ 1.,  5., 14., 17., 12., 16., 20.,  7.,  6.,  2.]),
#  array([-40.01284227, -29.92193117, -19.83102007,  -9.74010897,
#           0.35080212,  10.44171322,  20.53262432,  30.62353542,
#          40.71444651,  50.80535761,  60.89626871]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Piechart

# %%
x9=np.array([25,20,36,16,5])

# %%
plt.pie(x9)
# Out:
# ([<matplotlib.patches.Wedge at 0x2084fc06710>,
#   <matplotlib.patches.Wedge at 0x2084fc07050>,
#   <matplotlib.patches.Wedge at 0x2084fc07e50>,
#   <matplotlib.patches.Wedge at 0x20800004ed0>,
#   <matplotlib.patches.Wedge at 0x20800005ed0>],
#  [Text(0.7897031146679996, 0.7657473412840952, ''),
#   Text(-0.607601481198508, 0.9169626164928313, ''),
#   Text(-0.8129097722102662, -0.7410652483047991, ''),
#   Text(0.7657474152214336, -0.7897030429735556, ''),
#   Text(1.0869820386106088, -0.16873069589711656, '')])

# %%
mlabels=["rohit","panav","chetya","tanya","bitya"]
plt.pie(x9,labels=mlabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2080013d910>,
#   <matplotlib.patches.Wedge at 0x2080013e110>,
#   <matplotlib.patches.Wedge at 0x2080013f1d0>,
#   <matplotlib.patches.Wedge at 0x208001542d0>,
#   <matplotlib.patches.Wedge at 0x20800155210>],
#  [Text(0.7897031146679996, 0.7657473412840952, 'rohit'),
#   Text(-0.607601481198508, 0.9169626164928313, 'panav'),
#   Text(-0.8129097722102662, -0.7410652483047991, 'chetya'),
#   Text(0.7657474152214336, -0.7897030429735556, 'tanya'),
#   Text(1.0869820386106088, -0.16873069589711656, 'bitya')])

# %% [markdown]
# <h2>**** Explode****<h2>

# %%
e2=[0.1,0,0.2,0,0 ]
plt.pie(x9,labels=mlabels,explode=e2)
# Out:
# ([<matplotlib.patches.Wedge at 0x2080151bc90>,
#   <matplotlib.patches.Wedge at 0x20801524b10>,
#   <matplotlib.patches.Wedge at 0x20801525f10>,
#   <matplotlib.patches.Wedge at 0x20801527390>,
#   <matplotlib.patches.Wedge at 0x20801534610>],
#  [Text(0.861494306910545, 0.8353607359462856, 'rohit'),
#   Text(-0.607601481198508, 0.9169626164928313, 'panav'),
#   Text(-0.9607115489757692, -0.8758043843602171, 'chetya'),
#   Text(0.7657474152214336, -0.7897030429735556, 'tanya'),
#   Text(1.0869820386106088, -0.16873069589711656, 'bitya')])

# %%
e1=[0.1,0.1 ,0.1 ,0.2,0.1 ]
plt.pie(x9,labels=mlabels,explode=e1)
# Out:
# ([<matplotlib.patches.Wedge at 0x20801578910>,
#   <matplotlib.patches.Wedge at 0x208015793d0>,
#   <matplotlib.patches.Wedge at 0x2080157a450>,
#   <matplotlib.patches.Wedge at 0x2080157b710>,
#   <matplotlib.patches.Wedge at 0x20801584a90>],
#  [Text(0.861494306910545, 0.8353607359462856, 'rohit'),
#   Text(-0.6628379794892815, 1.000322854355816, 'panav'),
#   Text(-0.8868106605930176, -0.8084348163325081, 'chetya'),
#   Text(0.904974217988967, -0.933285414423293, 'tanya'),
#   Text(1.1857985875752095, -0.1840698500695817, 'bitya')])

# %% [markdown]
# <h2>****Shadow ****<h2>

# %%
plt.pie(x9,labels=mlabels,explode=e2,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x208015c4990>,
#   <matplotlib.patches.Wedge at 0x208015c5bd0>,
#   <matplotlib.patches.Wedge at 0x208015c7890>,
#   <matplotlib.patches.Wedge at 0x208015d1710>,
#   <matplotlib.patches.Wedge at 0x208015d3350>],
#  [Text(0.861494306910545, 0.8353607359462856, 'rohit'),
#   Text(-0.607601481198508, 0.9169626164928313, 'panav'),
#   Text(-0.9607115489757692, -0.8758043843602171, 'chetya'),
#   Text(0.7657474152214336, -0.7897030429735556, 'tanya'),
#   Text(1.0869820386106088, -0.16873069589711656, 'bitya')])

# %%
plt.pie(x9,labels=mlabels)
plt.legend(loc=1, fontsize='medium',)

# %% [raw]
#  numeric value:
#
#         ==================   =============
#         Location String      Location Code
#         ==================   =============
#         'best' (Axes only)   0
#         'upper right'        1
#         'upper left'         2
#         'lower left'         3
#         'lower right'        4
#         'right'              5
#         'center left'        6
#         'center right'       7
#         'lower center'       8
#         'upper center'       9
#         'center'             10
#         ==================   =============
